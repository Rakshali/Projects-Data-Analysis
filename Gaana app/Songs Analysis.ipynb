# %%
# !git clone https://github.com/Rakshali/Data-Analysis-Datasets
# Out:
# Cloning into 'Data-Analysis-Datasets'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (8/8), 1.15 MiB | 5.73 MiB/s, done.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data-Analysis-Datasets/Gaana/songs.csv')

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %% [markdown]
# 1. Exploratory Data Analysis

# %% [markdown]
# 1.1) Checking the NULL values

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# 1.2) Checking duplicate values

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %% [markdown]
# 1.3) Explore name column

# %%
print("Total number of values in column name:", len(df.name))
print("Number of unique values in column name:",df.name.nunique())
# Out:
# Total number of values in column name: 41354
# Number of unique values in column name: 31534

# %% [markdown]
# 1.4) Explore singer column

# %%
print("Total number of values in column singer:", len(df.singer))
print("Number of unique values in column singer:",df.singer.nunique())
# Out:
# Total number of values in column singer: 41354
# Number of unique values in column singer: 6196

# %% [markdown]
# 1.5) Explore singer_id column

# %%
print("Total number of values in column singer_id:", len(df.singer_id))
print("Number of unique values in column singer_id:",df.singer_id.nunique())
# Out:
# Total number of values in column singer_id: 41354
# Number of unique values in column singer_id: 6580

# %% [markdown]
# 1.6) Explore duration column

# %%
print("Total number of values in column duration:", len(df.duration))
print("Number of unique values in column duration:",df.duration.nunique())
# Out:
# Total number of values in column duration: 41354
# Number of unique values in column duration: 1309

# %% [markdown]
# 1.7) Explore link column

# %%
print("Total number of values in column link:", len(df.link))
print("Number of unique values in column link:",df.link.nunique())
# Out:
# Total number of values in column link: 41354
# Number of unique values in column link: 36361

# %% [markdown]
# 1.7.1) Counting the number of times of each link present in the dataframe

# %%
df.link.value_counts()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# 1.7.2) Finding a particular song in the dataframe

# %%
df[df.link == '/kya-khoob-lagti-ho']
# Out:
#                      name          singer                       singer_id  \
# 18180  Kya Khoob Lagti Ho  Kanchan|Mukesh  /artist/kanchan|/artist/mukesh
# 23173  Kya Khoob Lagti Ho  Kanchan|Mukesh  /artist/kanchan|/artist/mukesh
#
#       duration                 link language
# 18180    03:59  /kya-khoob-lagti-ho    Hindi
# 23173    03:59  /kya-khoob-lagti-ho      Old

# %% [markdown]
# 1.8) Explore language column

# %%
print("Total number of values in column language:", len(df.language))
print("Number of unique values in column language:",df.language.nunique())
# Out:
# Total number of values in column language: 41354
# Number of unique values in column language: 16

# %% [markdown]
# 1.8.1) Names of all the languages present in the dataframe

# %%
df.language.unique()
# Out:
# array(['Urdu', 'Gujarati', 'Tamil', 'Kannada', 'Rajasthani', 'Haryanvi',
#        'Punjabi', 'Hindi', 'Old', 'Malayalam', 'Marathi', 'Telugu',
#        'Odia', 'Bhojpuri', 'Assamese', 'Bengali'], dtype=object)

# %% [markdown]
# 1.8.2) Number of occurrences of each language present in the dataframe

# %%
df.language.value_counts()
# Out:
# language
# Telugu        4995
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %% [markdown]
# 1.8.3) Number of duplicate songs

# %%
print("Number of duplicate songs:",len(df.link) - df.link.nunique())
# Out:
# Number of duplicate songs: 4993

# %% [markdown]
# 2. Data Cleaning
#
# 2.1) Removing duplicate values as per ID
#
# 2.1.1) Number of songs we would get after removing duplicate songs

# %%
df[df['language'] != 'Old']['link'].nunique()
# Out:
# 36361

# %%
df[df.language == 'Old']
# Out:
#                                    name                         singer  \
# 23047         Bheegi Bheegi Raaton Mein  Kishore Kumar|Lata Mangeshkar
# 23048           Aap Ki Ankhon Mein Kuch  Kishore Kumar|Lata Mangeshkar
# 23049       Tum Aa Gaye Ho Noor Aa Gaya  Kishore Kumar|Lata Mangeshkar
# 23050            Hamen Tumse Pyar Kitna                  Kishore Kumar
# 23051              Tere Bina Zindagi Se  Kishore Kumar|Lata Mangeshkar
# ...                                 ...                            ...
# 28035  Nigahen Milane Ko Jee Chahta Hai                    Asha Bhosle
# 28036       Apne Hathon Ki Lakiron Mein                   Manhar Udhas
# 28037       Gori Chalo Na Hans Ki Chaal      Asha Bhosle|Mohammed Rafi
# 28038          Zindagi Ki Na Toote Ladi   Lata Mangeshkar|Nitin Mukesh
# 28039              Diwana Leke Aaya Hai                  Kishore Kumar
#
#                                            singer_id duration  \
# ...

# %%
df[df.language == 'Hindi']
# Out:
#                                    name                         singer  \
# 18054         Bheegi Bheegi Raaton Mein  Kishore Kumar|Lata Mangeshkar
# 18055           Aap Ki Ankhon Mein Kuch  Kishore Kumar|Lata Mangeshkar
# 18056       Tum Aa Gaye Ho Noor Aa Gaya  Kishore Kumar|Lata Mangeshkar
# 18057            Hamen Tumse Pyar Kitna                  Kishore Kumar
# 18058              Tere Bina Zindagi Se  Kishore Kumar|Lata Mangeshkar
# ...                                 ...                            ...
# 23042  Nigahen Milane Ko Jee Chahta Hai                    Asha Bhosle
# 23043       Apne Hathon Ki Lakiron Mein                   Manhar Udhas
# 23044       Gori Chalo Na Hans Ki Chaal      Asha Bhosle|Mohammed Rafi
# 23045          Zindagi Ki Na Toote Ladi   Lata Mangeshkar|Nitin Mukesh
# 23046              Diwana Leke Aaya Hai                  Kishore Kumar
#
#                                            singer_id duration  \
# ...

# %% [markdown]
# 2.1.2) Removing the duplicate songs by resetting the index

# %%
df = df[df.language != 'Old'].reset_index()

# %%
df
# Out:
#        index                                               name  \
# 0          0                              Dil - E - Nadan Tujhe
# 1          1                  Agar Hum Kahen Aur Woh Muskara De
# 2          2                                      Unke Dekhe Se
# 3          3            Yeh Na Thi Hamari Qismat - Chitra Singh
# 4          4                            Hazaron Khwahishen Aisi
# ...      ...                                                ...
# 36356  41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357  41351                                Ei Ki Go Shesh Daan
# 36358  41352                                       Ei Je Bangla
# 36359  41353                               Jatone Hridaye Rekho
# 36360  41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# ...

# %%
del df['index']

# %% [markdown]
# 2.2) Cleaning duration column and converting into seconds

# %%
durations = []
for i in df.duration:
  lst = i.split(":")
  if(len(lst) == 2):
    durations.append(int(lst[0]) * 60 + int(lst[1]))
  elif(len(lst) == 3):
    durations.append(int(lst[0]) * 3600 + int(lst[1]) * 60 + int(lst[2]))

#print(durations)

df.duration = durations

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 36356  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357                                Ei Ki Go Shesh Daan
# 36358                                       Ei Je Bangla
# 36359                               Jatone Hridaye Rekho
# 36360                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.duration.nunique()
# Out:
# 1309

# %%
df[df.duration >= 3600]
# Out:
#                                                    name  \
# 588              Aziz Mian - Ae ri Main to Prem Deewani
# 1441                                   Bohat Kathan Hai
# 3013         Dilawar Figaar - Shaakar Ka Qahet & Others
# 5556   Pudhiya Padhai (Full Length Audio Cinema) Part-1
# 6024   Pudhiya Padhai (Full Length Audio Cinema) Part-2
# ...                                                 ...
# 31382                              Naa Mora Alakimavemi
# 32488                                     Echatano Gala
# 33048                                           Padyams
# 33093           Thrimurthulu (Full Length Audio Cinema)
# 34339                                     Chum Chatakan
#
#                               singer  \
# 588                Aziz Miyan Qawwal
# 1441               Aziz Miyan Qawwal
# 3013                  Dilawar Figaar
# 5556   S. P. Balasubrahmanyam|Others
# 6024   S. P. Balasubrahmanyam|Others
# ...                              ...
# ...

# %% [markdown]
# 2.3) Removing "/artist" from singer_id column and splitting them based on ','

# %%
df.singer_id.str.split('|').explode().nunique()
# Out:
# 4528

# %%
df.singer.str.split('|').explode().nunique()
# Out:
# 3940

# %%
df['singer_id'] = df['singer_id'].str.replace('/artist/','').str.replace('|',',')

# %% [markdown]
# 2.4) Removing "|" from singer column and splitting them based on ','

# %%
df['singer'] = df['singer'].str.replace('|',',')

# %% [markdown]
# 2.5) Removing '/' from the link

# %%
df['link'] = df['link'].str.replace('/','')

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 36356  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357                                Ei Ki Go Shesh Daan
# 36358                                       Ei Je Bangla
# 36359                               Jatone Hridaye Rekho
# 36360                            Tomar Je Oi Haater Mala
#
#                                singer                            singer_id  \
# 0           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# 1           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# ...

# %% [markdown]
# 3. Data Analysis
#
# 3.1) Finding number of unique singers based on singer_id and singer column

# %%
lst = []

for i in df.singer_id:
  lst.extend(i.split(','))

print("Number of total number of singers:",len(lst))
print("Number of unique singers:",len(set(lst)))
print("Number of unique singers:",df.singer_id.str.split(',').explode().nunique())
print("Number of unique singers:",len(list(set(','.join(df.singer_id).split(',')))))
print("Unique singers:",list(set(','.join(df.singer_id).split(','))))
# Out:
# Number of total number of singers: 52539
# Number of unique singers: 4528
# Number of unique singers: 4528
# Number of unique singers: 4528
# ...

# %%
lst1 = []

for i in df['singer_id']:
  lst1.extend(i.split(','))

print(len(set(lst1)))
# Out:
# 4528

# %%
lst2 = []

for i in df['singer']:
  lst2.extend(i.split(','))

print(len(set(lst2)))
# Out:
# 3940

# %%
df[df.singer_id == 'na']
# Out:
#               name singer singer_id  duration            link language
# 31821  Theme Music     Na        na        96  theme-music-99   Telugu

# %%
lst4 = []

for i in df.singer:
  lst4.extend(i.split(','))

print("Number of singers:",len(lst4))
print("Number of unique singers:",df.singer.str.split(',').explode().nunique())
# Out:
# Number of singers: 52539
# Number of unique singers: 3940

# %%
len(lst)
# Out:
# 52539

# %%
lst = list(set(lst))
len(lst)
# Out:
# 4528

# %% [markdown]
# 3.2) Finding the number of songs sung by each singer

# %%
ind = int(input("Enter the index:"))
c = 0
for i in df.singer_id:
  if(lst[ind] in i):
    c += 1
print(lst[ind],c)
# Out:
# Enter the index:389
# rajashree-thosar 16

# %%
for i in range(len(lst)):
  c = 0
  for j in df.singer_id:
    if(lst[i] in j):
      c += 1
  print("**",i,"**",lst[i],c)
# Out:
# ** 0 ** h-p-gita 1
# ** 1 ** prayag-raj 1
# ** 2 ** euphoria 1
# ** 3 ** ashwini-t-n 2
# ** 4 ** gajanan-watve 2
# ** 5 ** bhai-samund-singh-ragi 9
# ** 6 ** madhuri-purandare 1
# ** 7 ** ratnamala-prakash 8
# ** 8 ** sudhir-phadle-31 1
# ** 9 ** mohini 30
# ** 10 ** gkvenkatesh 8
# ** 11 ** bela-sraver 1
# ** 12 ** suraiyya-khanum 1
# ** 13 ** akashvani-vadya-vrinda 1
# ** 14 ** asif-ali 1
# ** 15 ** sd-chauhan 1
# ** 16 ** suparnakanti-ghosh 1
# ** 17 ** paramjit-pali 6
# ** 18 ** aziz-miyan-qawwal 38
# ** 19 ** debashish-mahapatra 2
# ** 20 ** anayyar 14
# ** 21 ** kv-prasad-11 1
# ** 22 ** devashish-mahapatra 1
# ** 23 ** orchestra 25
# ** 24 ** mani-krishnaswami 1
# ** 25 ** javed-jaffrey 1
# ** 26 ** mayavati-bodade 3
# ** 27 ** sangeeta-mohapatra 12
# ** 28 ** bhupatdan-gadhavi 1
# ** 29 ** dilip-chowdhury 1
# ** 30 ** balaiah 2
# ** 31 ** e-v-saroja-1 1
# ** 32 ** mpn-ponnuswamy-36 1
# ** 33 ** ms-naseem 7
# ** 34 ** panna-quawal 4
# ** 35 ** justin-prabhakaran 2
# ...

# %% [markdown]
# 3.3) Finding the top 10 singers who have maximum number of songs

# %%
singers = list(set(lst))

# %%
from tqdm import tqdm

# %%
singer_lst = []
for singer in tqdm(singers):
  c = 0
  for i in df.singer_id:
    if(singer in i.split(',')):
      c += 1
  singer_lst.append([singer,c])
# Out:
# 100%|██████████| 4528/4528 [01:06<00:00, 68.45it/s]

# %%
singer_counts = df['singer_id'].str.split(',').explode().value_counts().sort_values(ascending = False).reset_index()
singer_counts.columns = ['singer','count']
singer_counts
# Out:
#                      singer  count
# 0     s-p-balasubrahamanyam   3617
# 1               p-suseela-2   3212
# 2                  s-janaki   2193
# 3             asha-bhosle-1   1981
# 4           lata-mangeshkar   1726
# ...                     ...    ...
# 4523              vanmali-8      1
# 4524    dr-aparna-mayekar-1      1
# 4525        sulochna-chavan      1
# 4526   chittaranjan-jena-14      1
# 4527    rabindranath-tagore      1
#
# [4528 rows x 2 columns]

# %%
len(singer_lst)
# Out:
# 4528

# %%
singer_lst
# Out:
# [['h-p-gita', 1],
#  ['prayag-raj', 1],
#  ['euphoria', 1],
#  ['ashwini-t-n', 2],
#  ['gajanan-watve', 2],
#  ['bhai-samund-singh-ragi', 9],
#  ['madhuri-purandare', 1],
#  ['ratnamala-prakash', 8],
#  ['sudhir-phadle-31', 1],
#  ['mohini', 1],
#  ['gkvenkatesh', 8],
#  ['bela-sraver', 1],
#  ['suraiyya-khanum', 1],
#  ['akashvani-vadya-vrinda', 1],
#  ['asif-ali', 1],
#  ['sd-chauhan', 1],
#  ['suparnakanti-ghosh', 1],
#  ['paramjit-pali', 6],
#  ['aziz-miyan-qawwal', 38],
#  ['debashish-mahapatra', 2],
#  ['anayyar', 14],
#  ['kv-prasad-11', 1],
#  ['devashish-mahapatra', 1],
#  ['orchestra', 12],
#  ['mani-krishnaswami', 1],
#  ['javed-jaffrey', 1],
#  ['mayavati-bodade', 3],
#  ['sangeeta-mohapatra', 12],
#  ['bhupatdan-gadhavi', 1],
#  ['dilip-chowdhury', 1],
#  ['balaiah', 1],
#  ['e-v-saroja-1', 1],
#  ['mpn-ponnuswamy-36', 1],
#  ['ms-naseem', 7],
#  ['panna-quawal', 4],
#  ['justin-prabhakaran', 2],
#  ['santha-kumari', 5],
#  ['ambilikuttan', 3],
#  ['kirpal-bawa', 4],
# ...

# %%
singer_df = pd.DataFrame(singer_lst, columns = ['singer','count'])

# %%
singer_df.sort_values(by = 'count', ascending = False).head(10)
# Out:
#                      singer  count
# 3981  s-p-balasubrahamanyam   3617
# 1615            p-suseela-2   3212
# 3596               s-janaki   2193
# 1652          asha-bhosle-1   1981
# 2374        lata-mangeshkar   1726
# 2431          kishore-kumar   1281
# 2049          mohammad-rafi   1223
# 4019            ghanatasala   1109
# 1119                 chorus   1108
# 657            pb-sreenivas    937

# %%
singers = list(set(','.join(df.singer_id).split(',')))
singers
# Out:
# ['h-p-gita',
#  'prayag-raj',
#  'euphoria',
#  'ashwini-t-n',
#  'gajanan-watve',
#  'bhai-samund-singh-ragi',
#  'madhuri-purandare',
#  'ratnamala-prakash',
#  'sudhir-phadle-31',
#  'mohini',
#  'gkvenkatesh',
#  'bela-sraver',
#  'suraiyya-khanum',
#  'akashvani-vadya-vrinda',
#  'asif-ali',
#  'sd-chauhan',
#  'suparnakanti-ghosh',
#  'paramjit-pali',
#  'aziz-miyan-qawwal',
#  'debashish-mahapatra',
#  'anayyar',
#  'kv-prasad-11',
#  'devashish-mahapatra',
#  'orchestra',
#  'mani-krishnaswami',
#  'javed-jaffrey',
#  'mayavati-bodade',
#  'sangeeta-mohapatra',
#  'bhupatdan-gadhavi',
#  'dilip-chowdhury',
#  'balaiah',
#  'e-v-saroja-1',
#  'mpn-ponnuswamy-36',
#  'ms-naseem',
#  'panna-quawal',
#  'justin-prabhakaran',
#  'santha-kumari',
#  'ambilikuttan',
#  'kirpal-bawa',
#  'pargan-singh-teji',
#  'nt-rama-rao-15',
#  'chittoor-v-nagaiah-109',
#  'om-pawar',
#  'ramila-gahlot',
#  'zahida-parveen',
#  'poorani',
#  'd-g-s-dhinakaran',
#  'mano-raj',
# ...

# %%
print(len(singers))
# Out:
# 4528

# %%
singer_df.sort_values(by = 'singer', ascending = False)
# Out:
#                    singer  count
# 4108          zul-vellani      2
# 3189       zubeeda-khanum     15
# 2780       zubaida-khanum     46
# 4142      zubaida-khannum      2
# 4278  zohrabai-ambalawali      1
# ...                   ...    ...
# 731            a-kasthuri      2
# 4067             a-k-vyas      3
# 2641         a-k-hangal-1      1
# 1305       a-j-muthuswamy      1
# 1632    a-chandrasekhar-1      1
#
# [4528 rows x 2 columns]

# %%
singer_df.to_csv('singer_df.csv',index = False)

# %%
new_singer_df = pd.read_csv('singer_df.csv')
new_singer_df.head(20)
# Out:
#                     singer  count
# 0                 h-p-gita      1
# 1               prayag-raj      1
# 2                 euphoria      1
# 3              ashwini-t-n      2
# 4            gajanan-watve      2
# 5   bhai-samund-singh-ragi      9
# 6        madhuri-purandare      1
# 7        ratnamala-prakash      8
# 8         sudhir-phadle-31      1
# 9                   mohini      1
# 10             gkvenkatesh      8
# 11             bela-sraver      1
# 12         suraiyya-khanum      1
# 13  akashvani-vadya-vrinda      1
# 14                asif-ali      1
# 15              sd-chauhan      1
# 16      suparnakanti-ghosh      1
# 17           paramjit-pali      6
# 18       aziz-miyan-qawwal     38
# 19     debashish-mahapatra      2

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 36356  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357                                Ei Ki Go Shesh Daan
# 36358                                       Ei Je Bangla
# 36359                               Jatone Hridaye Rekho
# 36360                            Tomar Je Oi Haater Mala
#
#                                singer                            singer_id  \
# 0           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# 1           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# ...

# %% [markdown]
# 3.4) Finding top 10 songs which have maximum duration

# %%
df.sort_values(by = 'duration', ascending = False).head(10)
# Out:
#                                name          singer       singer_id  duration  \
# 16093                    Haye Tumba  Dilshad Akhtar  dilshad-akhtar     25680
# 16352                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15000                Bum Bum Lahiri  Dilshad Akhtar  dilshad-akhtar     24720
# 15025          Kanu Atharu Bahoundi  Dilshad Akhtar  dilshad-akhtar     21840
# 14624  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
# 16022  Desi Bandri Vilayati Cheekan  Dilshad Akhtar  dilshad-akhtar     21780
# 15259        Kunda Khol Basantariye  Dilshad Akhtar  dilshad-akhtar     21720
# 16027                 Ghund Kad Lai  Dilshad Akhtar  dilshad-akhtar     20880
# 14655                 Ghund Kad Lai  Dilshad Akhtar  dilshad-akhtar     20880
# 14360               Man Wich Vasnai  Dilshad Akhtar  dilshad-akhtar     20580
#
#                                  link language
# 16093                      haye-tumba  Punjabi
# ...

# %% [markdown]
# 3.5) Finding punjabi songs which have duration from 3 to 4 minutes

# %%
df_new = df[df.language == 'Punjabi']
df_new = df_new[df_new.duration >= 180]
df_new = df_new[df_new.duration <= 240]

df_new
# Out:
#                                          name                       singer  \
# 14236                      Pehle Lalkare Naal  Amar Singh Chamkila,Amarjot
# 14244                          Dat Khol Mitra  Amar Singh Chamkila,Amarjot
# 14245               Bhul Gai Main Ghund Kadna  Amar Singh Chamkila,Amarjot
# 14246              Bach Ke Reha Kar Tun Nakro  Amar Singh Chamkila,Amarjot
# 14247           Kaali Teri Gut - Punjabi Geet            Asa Singh Mastana
# ...                                       ...                          ...
# 18028  Tere Qadman Wich (From "Balocha Daku")                 Tarannum Naz
# 18033                         Aaj Dumroo Bole                 Nahid Akhtar
# 18035                       Meri Uthdi Jawani                 Nahid Akhtar
# 18037                      Bol Bol We Dopatia                 Nahid Akhtar
# 18050                     Aeh Dunya Lag Di Ae                   Noor Jehan
#
# ...

# %%
df[(df['language'] == "Punjabi") & (df['duration'] >= 180) & (df['duration'] <= 240)]
# Out:
#                                          name                       singer  \
# 14236                      Pehle Lalkare Naal  Amar Singh Chamkila,Amarjot
# 14244                          Dat Khol Mitra  Amar Singh Chamkila,Amarjot
# 14245               Bhul Gai Main Ghund Kadna  Amar Singh Chamkila,Amarjot
# 14246              Bach Ke Reha Kar Tun Nakro  Amar Singh Chamkila,Amarjot
# 14247           Kaali Teri Gut - Punjabi Geet            Asa Singh Mastana
# ...                                       ...                          ...
# 18028  Tere Qadman Wich (From "Balocha Daku")                 Tarannum Naz
# 18033                         Aaj Dumroo Bole                 Nahid Akhtar
# 18035                       Meri Uthdi Jawani                 Nahid Akhtar
# 18037                      Bol Bol We Dopatia                 Nahid Akhtar
# 18050                     Aeh Dunya Lag Di Ae                   Noor Jehan
#
# ...

# %% [markdown]
# 3.6) Largest collaboration in the history of songs

# %%
lst = []

for i in df.singer:
  lst.append(len(i.split(',')))

df['number_of_singers'] = lst

df.sort_values(by = 'number_of_singers', ascending = False).head(10)
# Out:
#                                           name  \
# 36054  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 16506                           Ungla Te Munde
# 16124                    Mere Viah La Babla Ve
# 16069                    Charkhe Di Tand Warga
# 14958                       Ag To Buja De Illo
# 15668                           Main Akh Maari
# 15685                      Ley Chail Ve Mittra
# 16026                  Saali Wekh Patole Vargi
# 15711             Baaba Ho Laa Ke Bhabi Laa Ra
# 15882                    Chunni Thalle Ambiaan
#
#                                                   singer  \
# 36054  Asha Devi,Kazi Sabyasachi,Lalita Dhar Chowdhur...
# 16506  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16124  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16069  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 14958  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 15668  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# ...

# %% [markdown]
# OR

# %%
df['number_of_singers'] = df.singer.str.split(',').str.len()
df.sort_values(by = 'number_of_singers', ascending = False).head(10)
# Out:
#                                           name  \
# 36054  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 16506                           Ungla Te Munde
# 16124                    Mere Viah La Babla Ve
# 16069                    Charkhe Di Tand Warga
# 14958                       Ag To Buja De Illo
# 15668                           Main Akh Maari
# 15685                      Ley Chail Ve Mittra
# 16026                  Saali Wekh Patole Vargi
# 15711             Baaba Ho Laa Ke Bhabi Laa Ra
# 15882                    Chunni Thalle Ambiaan
#
#                                                   singer  \
# 36054  Asha Devi,Kazi Sabyasachi,Lalita Dhar Chowdhur...
# 16506  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16124  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16069  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 14958  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 15668  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# ...

# %%
df[df.language == 'Urdu'].sort_values(by = 'number_of_singers', ascending = False).head(10)
# Out:
#                                         name  \
# 69                                    Ibteda
# 28                                    Ibteda
# 1762                               Sathi Koi
# 446                       Woh Chaman Ki Sair
# 1989                              Jane Kiyun
# 71               Hum Mein Hi Thi Na Koi Baat
# 365                    Guzar Gaya Hai Zamana
# 1461                                End Part
# 1803                      Chopaye The Tailer
# 1955  Apne Baron Se Main Ne (From "Faisla" )
#
#                                                  singer  \
# 69    Chitra Singh,Gulzar,Naseeruddin Shah,Vinod Seh...
# 28    Chitra Singh,Gulzar,Naseeruddin Shah,Vinod Seh...
# 1762                Ali Abbas,Khalid Ghayur,Jamal Ghani
# 446        Ustad Ali Ahmed Hussain,Mohd. Hussain,Chorus
# 1989                Ali Abbas,Khalid Ghayur,Jamal Ghani
# 71    Chitra Singh,Jagjit Singh,Supported By Talents...
# 365        Ustad Ali Ahmed Hussain,Mohd. Hussain,Chorus
# ...

# %%
df[df.language == 'Bengali'].sort_values(by = 'number_of_singers', ascending = False).head(10)
# Out:
#                                           name  \
# 36054  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 36117         Basanta (Part-1) With Recitation
# 36235       Lord Bhanu (1 and 2)(Comic Sketch)
# 35980            Bhanusingher Padavali (Drama)
# 36307     Bhanu Elo Kolkatay - 1 And 2 - Comic
# 35822                                  Ghoomer
# 36017                     Ore Mon Ke Emon Daga
# 36234   Amanush - Dialogue - Maap Korben Huzur
# 35755                            Eureka Eureka
# 35466                Kato Naree Achhe E Gokule
#
#                                                   singer  \
# 36054  Asha Devi,Kazi Sabyasachi,Lalita Dhar Chowdhur...
# 36117  Arghya Sen,Banani Ghosh,Chinmoy Chatterjee,Dwi...
# 36235  Basabi Ghatak,Bithi Ganguly,Chandidas Chakrabo...
# 35980  Banani Ghosh,Bani Tagore,Bela Mukherjee,Kanika...
# 36307  Sudhin Mukherjee,Sushil Das,Vivekananda Roy,Bh...
# 35822  Om Pawar,Shamim,Rehana Mirza,Shiv Ram,Master A...
# ...

# %%
len(df[df.language == 'Bengali'])
# Out:
# 958

# %%
df[df['number_of_singers'] <= 3].sort_values(by = 'number_of_singers', ascending = False)
# Out:
#                                          name  \
# 13190                       Ananda Anandavene
# 6757                       Naan Paadum Paadal
# 27814                   Maharashtrache Kinari
# 27817               Diwas Ugvuni Varkiti Aala
# 12432                       Bhaja Gangaadhara
# ...                                       ...
# 6282                       O Maanida Jaathiye
# 19423                     Aesi Haseen Chandni
# 19422  Hare Krishna (Mahamantra) (Version, 2)
# 6283                           Ulagam Aayiram
# 36360                 Tomar Je Oi Haater Mala
#
#                                                 singer  \
# 13190                Mano,Manjula Gururaj,Rama Aravind
# 6757        T.M. Soundararajan,L.R. Anjali,S.N. Shobha
# 27814  Pushpa Pagdhare,Radha Dhareshwar,Kisan Killekar
# 27817                Ghogad Fem,Pawar Sobat,Shakuntala
# 12432       P.B. Sreenivas,Vijayalakshmi Sharma,Chorus
# ...                                                ...
# ...

# %%
df[df['number_of_singers'] >= 3].sort_values(by = 'number_of_singers', ascending = False)
# Out:
#                                           name  \
# 36054  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 16069                    Charkhe Di Tand Warga
# 15114               Nee Tu Laa Ke Bhabi Laa Ra
# 16502                           Tharki Rann De
# 16506                           Ungla Te Munde
# ...                                        ...
# 18570                 Gazar Ne Kiya Hai Ishara
# 18514                      Aye Sanam Tere Liye
# 18505                 Mere Paas Aao Mere Dosto
# 18492                   Har Dil Jo Pyar Karega
# 19992                          Qurbani Qurbani
#
#                                                   singer  \
# 36054  Asha Devi,Kazi Sabyasachi,Lalita Dhar Chowdhur...
# 16069  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 15114  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16502  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16506  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# ...

# %%
df[df['number_of_singers'] >= 3].sort_values(by = 'number_of_singers', ascending = False)
# Out:
#                                           name  \
# 36054  Neel Kamal Lal Kamal - Thakurmaar Jhuli
# 16069                    Charkhe Di Tand Warga
# 15114               Nee Tu Laa Ke Bhabi Laa Ra
# 16502                           Tharki Rann De
# 16506                           Ungla Te Munde
# ...                                        ...
# 18570                 Gazar Ne Kiya Hai Ishara
# 18514                      Aye Sanam Tere Liye
# 18505                 Mere Paas Aao Mere Dosto
# 18492                   Har Dil Jo Pyar Karega
# 19992                          Qurbani Qurbani
#
#                                                   singer  \
# 36054  Asha Devi,Kazi Sabyasachi,Lalita Dhar Chowdhur...
# 16069  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 15114  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16502  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# 16506  Karam Singh Bhatti,Sukhchain Kaur,Sarabji Jagt...
# ...

# %%
df[df['singer'] == 'Jagjit Singh']['language'].nunique()
# Out:
# 4

# %%
df[df['singer'] == 'Jagjit Singh']['language'].unique()
# Out:
# array(['Urdu', 'Gujarati', 'Punjabi', 'Hindi'], dtype=object)

# %%
df_jagjit_singh = df[df['singer'] == 'Jagjit Singh']
df_jagjit_singh
# Out:
#                                     name        singer        singer_id  \
# 2                          Unke Dekhe Se  Jagjit Singh  jagjeet-singh-1
# 4                Hazaron Khwahishen Aisi  Jagjit Singh  jagjeet-singh-1
# 7            Tum Itna Jo Muskura Rahe Ho  Jagjit Singh  jagjeet-singh-1
# 10          Zindagi Se Badi Saza Hi Nahi  Jagjit Singh  jagjeet-singh-1
# 11                 Kabse Hoon Kya Bataon  Jagjit Singh  jagjeet-singh-1
# ...                                  ...           ...              ...
# 22100  Woh Kagaz Ki Kasti (Part 1 And 2)  Jagjit Singh  jagjeet-singh-1
# 22164       Woh Kagaz Ki Kashti (Part 2)  Jagjit Singh  jagjeet-singh-1
# 22376         Tujhse Milne Ki Saza Denge  Jagjit Singh  jagjeet-singh-1
# 22400               Pyar Mujh Se Jo Kiya  Jagjit Singh  jagjeet-singh-1
# 22859       Shayad Main Zindagi Ki Sahar  Jagjit Singh  jagjeet-singh-1
#
#        duration                            link language  number_of_singers
# ...

# %%
df['singer_id'].str.split(',')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df['singer_id'].str.split(',').explode()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df['singer_id'].str.split(',').explode().value_counts()
# Out:
# singer_id
# s-p-balasubrahamanyam       3617
# p-suseela-2                 3212
# s-janaki                    2193
# asha-bhosle-1               1981
# lata-mangeshkar             1726
#                             ...
# inayat-ali                     1
# jaswant-singh-sandila-21       1
# meena-rai-3                    1
# arpana-chaudhary-3             1
# rabindranath-tagore            1
# Name: count, Length: 4528, dtype: int64

# %%
sum(df['singer'].str.split(',').explode() == 'Jagjit Singh')
# Out:
# 184

# %%
df_jagjit_singh.groupby('language').size()
# Out:
# language
# Gujarati     1
# Hindi       52
# Punjabi     27
# Urdu        40
# dtype: int64

# %%
df_jagjit_singh.groupby('language').sum()['duration']
# Out:
# language
# Gujarati      215
# Hindi       16201
# Punjabi      8368
# Urdu        11036
# Name: duration, dtype: int64

# %%
df_jagjit_singh.groupby('language')['duration'].mean()
# Out:
# language
# Gujarati    215.000000
# Hindi       311.557692
# Punjabi     309.925926
# Urdu        275.900000
# Name: duration, dtype: float64

# %%
df.groupby('language')['duration'].mean().sort_values(ascending = False)
# Out:
# language
# Punjabi       448.317968
# Urdu          410.692875
# Bhojpuri      364.073218
# Haryanvi      320.004386
# Telugu        314.183584
# Hindi         310.096936
# Rajasthani    291.040665
# Marathi       282.762290
# Tamil         273.258927
# Gujarati      271.632151
# Odia          257.629787
# Bengali       255.179541
# Kannada       252.726890
# Malayalam     242.609603
# Assamese      228.325967
# Name: duration, dtype: float64

# %%
df.groupby('language')['duration'].mean().sort_values(ascending = False).head(5)
# Out:
# language
# Punjabi     448.317968
# Urdu        410.692875
# Bhojpuri    364.073218
# Haryanvi    320.004386
# Telugu      314.183584
# Name: duration, dtype: float64

# %% [markdown]
# ## Graphs

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 36356  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 36357                                Ei Ki Go Shesh Daan
# 36358                                       Ei Je Bangla
# 36359                               Jatone Hridaye Rekho
# 36360                            Tomar Je Oi Haater Mala
#
#                                singer                            singer_id  \
# 0           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# 1           Chitra Singh,Jagjit Singh         chitra-singh,jagjeet-singh-1
# ...

# %%
singer_counts
# Out:
#                      singer  count
# 0     s-p-balasubrahamanyam   3617
# 1               p-suseela-2   3212
# 2                  s-janaki   2193
# 3             asha-bhosle-1   1981
# 4           lata-mangeshkar   1726
# ...                     ...    ...
# 4523              vanmali-8      1
# 4524    dr-aparna-mayekar-1      1
# 4525        sulochna-chavan      1
# 4526   chittaranjan-jena-14      1
# 4527    rabindranath-tagore      1
#
# [4528 rows x 2 columns]

# %% [markdown]
# Number of songs sung by each singer

# %%
singer_counts.head(30).plot(kind = 'bar',x = 'singer',y = 'count')
# Out:
# <Axes: xlabel='singer'>

# %% [markdown]
# Number of singers sang each song

# %%
df.tail(20).plot(kind = 'bar',x = 'name',y = 'number_of_singers')
# Out:
# <Axes: xlabel='name'>

# %% [markdown]
# Number of songs in each language

# %%
language_counts = df.language.value_counts().reset_index()
language_counts.columns = ['language','count']
language_counts
# Out:
#       language  count
# 0       Telugu   4995
# 1        Hindi   4993
# 2      Marathi   4699
# 3        Tamil   4677
# 4      Punjabi   3818
# 5      Kannada   3559
# 6         Urdu   3116
# 7     Gujarati   2115
# 8      Bengali    958
# 9         Odia    940
# 10    Assamese    724
# 11  Rajasthani    541
# 12    Bhojpuri    519
# 13   Malayalam    479
# 14    Haryanvi    228

# %%
language_counts.plot(kind = 'bar',x = 'language',y = 'count')
# Out:
# <Axes: xlabel='language'>

# %%
language_counts.plot(kind = 'pie', y = 'count',autopct = '%1.1f%%',radius = 0.6,labeldistance=1.5,pctdistance = 1.2,textprops={'fontsize': 6})
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Number of songs in specific duration

# %%
bins = [0, 180, 240, 300, float('inf')]
durations_grouped = pd.cut(df['duration'], bins=bins, labels=['< 3 min', '3-4 min', '4-5 min', '> 5 min'])
duration_counts = durations_grouped.value_counts().reset_index()
duration_counts.columns = ['duration','count']
duration_counts
# Out:
#   duration  count
# 0  3-4 min  12672
# 1  > 5 min  10817
# 2  4-5 min   9760
# 3  < 3 min   3112

# %%
duration_counts.plot(kind='bar', title = 'Distribution of Song Durations',x = 'duration', y = 'count')
# Out:
# <Axes: title={'center': 'Distribution of Song Durations'}, xlabel='duration'>

# %%
short_threshold = 180  # Seconds
long_threshold = 300  # Seconds
categorized = pd.cut(df['duration'], bins=[0, short_threshold, long_threshold, float('inf')],
                               labels=['Short (< 3 min)', 'Medium (3-5 min)', 'Long (> 5 min)'])
duration_categorized = categorized.value_counts().reset_index()
duration_categorized.columns = ['Duration Category','Count']
duration_categorized
# Out:
#   Duration Category  Count
# 0  Medium (3-5 min)  22432
# 1    Long (> 5 min)  10817
# 2   Short (< 3 min)   3112

# %%
duration_categorized.plot(kind='bar', title = 'Distribution of Song Lengths',x = 'Duration Category', y = 'Count')
# Out:
# <Axes: title={'center': 'Distribution of Song Lengths'}, xlabel='Duration Category'>
